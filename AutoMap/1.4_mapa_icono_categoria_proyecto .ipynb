# %% [markdown]
# ## Archivo de creacion del mapa: FILTRO CATEGORIA PROYECTO

# %% [markdown]
# ### 1_ Preparamos el entorno

# %% [markdown]
# **Importamos librerias**

# %%
# Preliminares
import re
import warnings

warnings.filterwarnings('ignore')

from math import radians

import folium
import matplotlib.cm as cm
import numpy as np
import openpyxl
import pandas as pd
from folium import CustomIcon
from folium.plugins import HeatMap, MarkerCluster
from matplotlib.colors import to_hex
from sklearn.metrics.pairwise import haversine_distances

# %% [markdown]
# **Cargamos los set**

# %%
# Dataframe Camiones estacionados
estacionados_camion = pd.read_excel("./estacionados_camion.xlsx", engine="openpyxl")

# Dataframe clientes 
ubi_cliente = pd.read_excel("./ubi_cliente.xlsx", engine="openpyxl")

# Tareas.xlsx
df_tareas = pd.read_excel('./Tareas-limpio.xlsx', engine="openpyxl")

# %% [markdown]
# **Cargamos ubicaciones extra Abitab,Red pagos, Empresa, Casas**

# %%
# Abitab y red pagos
lugares_pago = {
        'CODIGO': [200000, 200002, 200003, 200005, 200006, 200007, 200008, 200009, 200010, 200011, 200012, 200013, 200014, 200015, 200016, 200017, 200018, 200019, 200020, 200021, 200022, 200023, 200024, 200025, 200026, 200027, 200028, 200029, 200030, 200031],
        'NOMCLI': ['Abitab', 'ABITAB 12/18', 'Abitab', 'Abitab Ruta 87', 'Abitab 12-21', 'Abitab', 'Abitab', 'Cambilex', 'Abitab', 'Abitab', 'Abitab', 'Abitab', 'Abitab', 'Abitab', 'Abitab Agencia 18/09', 'Redpagos Minimercado Nico', 'Red Pagos El Dorado, Las Toscas', 'Redpagos Bachino', 'Redpagos San Luis', 'Redpagos La Tuna', 'Redpagos Provision San Jorge', 'Red Pagos', 'RedPagos', 'RedPagos', 'Cambilex', 'Redpagos Salinas', 'Redpagos Salinas Norte', 'Redpagos Pinamar', 'Redpagos Agencias Migues', 'Redpagos Saucedo'],
        'LATITUD': [-34.7773749, -34.778762, -34.7769439, -34.7722784, -34.7717067, -34.7576624, -34.7714756, -34.772715, -34.7554596, -34.7673311, -34.7506218, -34.758673, -34.769283, -34.7701505, -34.6003052, -34.79286, -34.7710358, -34.7592078, -34.7663154, -34.7801148, -34.6832898, -34.7499177, -34.7741445, -34.7679195, -34.7773725, -34.7758541, -34.77187, -34.778569, -34.4884583, -34.5999389],
        'LONGITUD': [-55.8391627, -55.8620459, -55.8489382, -55.8413815, -55.8195923, -55.766793, -55.7620991, -55.7637416, -55.7246934, -55.7220688, -55.7094748, -55.677871, -55.6553415, -55.5763933, -55.4663981, -55.49211, -55.7337499, -55.6766295, -55.5899085, -55.5607396, -55.7024884, -55.7083951, -55.7615713, -55.767487, -55.8391636, -55.8397048, -55.84086, -55.862882, -55.630918, -55.4665898]
    }

# Crear DataFrame
lugares_pago_df = pd.DataFrame(lugares_pago)

# ___________________________________________________________________________

# Añadir lugares empresa **Codigo 200.000 a 200032**
ubi_empresa = {
        'CODIGO': [100001, 100002, 100003, 100004, 100005,100000,],
        'NOMCLI': ['CASA DARIO', 'CASA HUGO', 'CASA CONRADO', 'CASA MIGUEL', 'CASA MARTIN','EMPRESA'],
        'LATITUD': [-34.770962, -34.76416, -34.766187, -34.787831, -34.761527,-34.771148],
        'LONGITUD': [-55.742166, -55.86347, -55.780495, -55.850621, -55.74736, -55.758]
    }
df_ubi_empresa = pd.DataFrame(ubi_empresa)

# Coordenadas de "EMPRESA"
coords_empresa = [-34.771148, -55.758]

# Umbral de distancia para considerar que un camión está en "EMPRESA"
umbral_distancia = 0.00001

# %% [markdown]
# Iconos especiales camiones numero_placa

# %%
# Diccionario de iconos personalizados (RUTA)
iconos_camion = {
    'AAW4251': '../num_placa_PNG/AAW4251.png',
    'BERLINGO7008': '../num_placa_PNG/BERLINGO7008.png',
    'BYD1006': '../num_placa_PNG/BYD1006.png',
    'CAA1076': '../num_placa_PNG/CAA1076.png'
}

# Normalizar las claves del diccionario de iconos
iconos_camion_normalizado = {key.replace(' ', '').upper(): value for key, value in iconos_camion.items()}

# %%
# Definir los colores personalizados para cada categoría
colores_categoria = {
    'Clientes Especiales': 'yellow',
    'Visitas Periódicas': 'green',  # Recomendado
    'Rutas': 'blue',
    'Creditos': 'red',
    'Otros': 'gray'  # Recomendado
}

# Definir los íconos Font Awesome para cada categoría
iconos_categoria = {
    'Clientes Especiales': 'fa-star',
    'Visitas Periódicas': 'fa-repeat',
    'Rutas': 'fa-map-marker',
    'Creditos': 'fa-credit-card',
    'Otros': 'fa-info-circle'
}

# %%
# Coordenadas de "EMPRESA"
coords_empresa = [-34.771148, -55.758]

# Umbral de distancia para considerar que un camión está en "EMPRESA"
umbral_distancia = 0.00001

# %%
# Cálculo de distancias (haversine)
def calcular_distancia(lat1, lon1, lat2, lon2):
    return haversine_distances([[radians(lat1), radians(lon1)], [radians(lat2), radians(lon2)]])[0][1]

# %%
# Crear el mapeo de codigo a categoria
codigo_categoria_map = dict(zip(df_tareas['CODIGO'], df_tareas['CATEGORIA']))

print("Mapeo de CODIGO a CATEGORIA:")
for codigo, categoria in codigo_categoria_map.items():
    print(f"Código: {codigo}, Categoría: {categoria}")
# Out:
# Mapeo de CODIGO a CATEGORIA:
# Código: 12239, Categoría: Clientes Especiales
# Código: 62005, Categoría: Clientes Especiales
# Código: 77778, Categoría: Clientes Especiales
# Código: 12869, Categoría: Clientes Especiales
# Código: 22024, Categoría: Clientes Especiales
# Código: 12450, Categoría: Clientes Especiales
# Código: 44444, Categoría: Clientes Especiales
# Código: 55555, Categoría: Clientes Especiales
# Código: 11545, Categoría: Clientes Especiales
# Código: 11891, Categoría: Clientes Especiales
# Código: 41111, Categoría: Clientes Especiales
# Código: 12904, Categoría: Clientes Especiales
# Código: 12500, Categoría: Clientes Especiales
# Código: 12920, Categoría: Clientes Especiales
# Código: 21955, Categoría: Clientes Especiales
# Código: 12286, Categoría: Clientes Especiales
# Código: 12674, Categoría: Clientes Especiales
# Código: 11881, Categoría: Clientes Especiales
# Código: 21412, Categoría: Clientes Especiales
# Código: 12284, Categoría: Clientes Especiales
# Código: 11787, Categoría: Clientes Especiales
# Código: 23200, Categoría: Clientes Especiales
# Código: 22336, Categoría: Clientes Especiales
# Código: 22167, Categoría: Clientes Especiales
# Código: 22753, Categoría: Clientes Especiales
# Código: 22170, Categoría: Clientes Especiales
# Código: 41911, Categoría: Clientes Especiales
# Código: 12326, Categoría: Clientes Especiales
# Código: 62915, Categoría: Clientes Especiales
# Código: 85025, Categoría: Clientes Especiales
# Código: 12435, Categoría: Clientes Especiales
# Código: 12289, Categoría: Clientes Especiales
# Código: 11895, Categoría: Clientes Especiales
# Código: 12000, Categoría: Clientes Especiales
# Código: 12800, Categoría: Clientes Especiales
# Código: 22980, Categoría: Clientes Especiales
# Código: 62008, Categoría: Clientes Especiales
# Código: 81061, Categoría: Clientes Especiales
# Código: 41972, Categoría: Clientes Especiales
# Código: 22338, Categoría: Clientes Especiales
# Código: nan, Categoría: Visitas Periódicas
# Código: 81062, Categoría: Visitas Periódicas
# Código: 62868, Categoría: Visitas Periódicas
# Código: 81063, Categoría: Visitas Periódicas
# Código: 11901, Categoría: Visitas Periódicas
# Código: 12862, Categoría: Visitas Periódicas
# Código: 81190, Categoría: Visitas Periódicas
# Código: 81158, Categoría: Visitas Periódicas
# Código: 81205, Categoría: Visitas Periódicas
# Código: 81051, Categoría: Visitas Periódicas
# Código: 81074, Categoría: Visitas Periódicas
# Código: 81002, Categoría: Visitas Periódicas
# Código: 81012, Categoría: Visitas Periódicas
# Código: 81159, Categoría: Visitas Periódicas
# Código: 81215, Categoría: Visitas Periódicas
# Código: 81065, Categoría: Visitas Periódicas
# Código: 81004, Categoría: Visitas Periódicas
# Código: 81134, Categoría: Visitas Periódicas
# Código: 81064, Categoría: Visitas Periódicas
# Código: 81059, Categoría: Visitas Periódicas
# Código: 11997, Categoría: Visitas Periódicas
# Código: 11580, Categoría: Visitas Periódicas
# Código: 81069, Categoría: Visitas Periódicas
# Código: 81220, Categoría: Visitas Periódicas
# Código: 13003, Categoría: Visitas Periódicas
# Código: 81221, Categoría: Visitas Periódicas
# Código: 81011, Categoría: Visitas Periódicas
# Código: 81067, Categoría: Visitas Periódicas
# Código: 13090, Categoría: Visitas Periódicas
# Código: 62980, Categoría: Visitas Periódicas
# Código: 81068, Categoría: Visitas Periódicas
# Código: 81006, Categoría: Visitas Periódicas
# Código: 22041, Categoría: Visitas Periódicas
# Código: 85001, Categoría: Visitas Periódicas
# Código: 81053, Categoría: Visitas Periódicas
# Código: 81014, Categoría: Visitas Periódicas
# Código: ***NOMBRE***; ...81162, Categoría: Visitas Periódicas
# Código: 11169, Categoría: Visitas Periódicas
# Código: 81075, Categoría: Visitas Periódicas
# Código: 81120, Categoría: Visitas Periódicas
# Código: 12327, Categoría: Visitas Periódicas
# Código: 41200, Categoría: Visitas Periódicas
# Código: 41925, Categoría: Visitas Periódicas
# Código: 41815, Categoría: Visitas Periódicas
# Código: 85024, Categoría: Visitas Periódicas
# Código: 82008, Categoría: Visitas Periódicas
# Código: 11975, Categoría: Rutas
# Código: 22351, Categoría: Rutas
# Código: 22138, Categoría: Rutas
# Código: 80100, Categoría: Rutas
# Código: 80261, Categoría: Rutas
# Código: 80169, Categoría: Rutas
# Código: 80250, Categoría: Rutas
# Código: 80230, Categoría: Rutas
# Código: 23075, Categoría: Rutas
# Código: 80287, Categoría: Rutas
# Código: 23040, Categoría: Rutas
# Código: 80288, Categoría: Rutas
# Código: 23190, Categoría: Rutas
# Código: 23175, Categoría: Rutas
# Código: 22360, Categoría: Rutas
# Código: 23055, Categoría: Rutas
# Código: 23155, Categoría: Rutas
# Código: 23230, Categoría: Rutas
# Código: 22037, Categoría: Rutas
# Código: 22873, Categoría: Rutas
# Código: 22038, Categoría: Rutas
# Código: 80280, Categoría: Rutas
# Código: 80236, Categoría: Rutas
# Código: 22759, Categoría: Rutas
# Código: 22903, Categoría: Rutas
# Código: 80067, Categoría: Rutas
# Código: 80174, Categoría: Rutas
# Código: 80285, Categoría: Rutas
# Código: 22161, Categoría: Rutas
# Código: 22159, Categoría: Rutas
# Código: 22910, Categoría: Rutas
# Código: 22175, Categoría: Rutas
# Código: 80237, Categoría: Rutas
# Código: 23280, Categoría: Rutas
# Código: 22049, Categoría: Rutas
# Código: 80189, Categoría: Rutas
# Código: 80279, Categoría: Rutas
# Código: 80212, Categoría: Rutas
# Código: 80268, Categoría: Rutas
# Código: 22036, Categoría: Rutas
# Código: 80246, Categoría: Rutas
# Código: 80257, Categoría: Rutas
# Código: 80233, Categoría: Rutas
# Código: 80259, Categoría: Rutas
# Código: 80138, Categoría: Rutas
# Código: 80146, Categoría: Rutas
# Código: 80181, Categoría: Rutas
# Código: 80296, Categoría: Rutas
# Código: 22644, Categoría: Rutas
# Código: 22144, Categoría: Rutas
# Código: 11868, Categoría: Rutas
# Código: 80126, Categoría: Rutas
# Código: 80116, Categoría: Rutas
# Código: 22157, Categoría: Rutas
# Código: 80106, Categoría: Rutas
# Código: 80186, Categoría: Rutas
# Código: 23180, Categoría: Rutas
# Código: 22163, Categoría: Rutas
# Código: 23450, Categoría: Rutas
# Código: 80109, Categoría: Rutas
# Código: 80258, Categoría: Rutas
# Código: 22141, Categoría: Rutas
# Código: 80103, Categoría: Rutas
# Código: 80153, Categoría: Rutas
# Código: 22791, Categoría: Rutas
# Código: 22922, Categoría: Rutas
# Código: 61905, Categoría: Rutas
# Código: 23120, Categoría: Rutas
# Código: 61642, Categoría: Rutas
# Código: 61731, Categoría: Rutas
# Código: 61428, Categoría: Rutas
# Código: 61767, Categoría: Rutas
# Código: 61493, Categoría: Rutas
# Código: 61920, Categoría: Rutas
# Código: 61494, Categoría: Rutas
# Código: 61833, Categoría: Rutas
# Código: 80214, Categoría: Rutas
# Código: 80134, Categoría: Rutas
# Código: 22146, Categoría: Rutas
# Código: 22914, Categoría: Rutas
# Código: 80247, Categoría: Rutas
# Código: 80263, Categoría: Rutas
# Código: 80262, Categoría: Rutas
# Código: 80265, Categoría: Rutas
# Código: 80267, Categoría: Rutas
# Código: 80281, Categoría: Rutas
# Código: 80283, Categoría: Rutas
# Código: 80292, Categoría: Rutas
# Código: 23030, Categoría: Rutas
# Código: 21615, Categoría: Rutas
# Código: 80191, Categoría: Rutas
# Código: 21420, Categoría: Rutas
# Código: 80248, Categoría: Rutas
# Código: 21418, Categoría: Rutas
# Código: 21417, Categoría: Rutas
# Código: 21207, Categoría: Rutas
# Código: 80284, Categoría: Rutas
# Código: 80167, Categoría: Rutas
# Código: 80164, Categoría: Rutas
# Código: 80125, Categoría: Rutas
# Código: 80290, Categoría: Rutas
# Código: 21391, Categoría: Rutas
# Código: 21430, Categoría: Rutas
# Código: 80242, Categoría: Rutas
# Código: 21393, Categoría: Rutas
# Código: 80107, Categoría: Rutas
# Código: 21915, Categoría: Rutas
# Código: 21925, Categoría: Rutas
# Código: 80179, Categoría: Rutas
# Código: 23060, Categoría: Rutas
# Código: 22996, Categoría: Rutas
# Código: 12345, Categoría: Rutas
# Código: 22990, Categoría: Rutas
# Código: 80231, Categoría: Rutas
# Código: 23405, Categoría: Rutas
# Código: 80291, Categoría: Rutas
# Código: 80293, Categoría: Rutas
# Código: 80294, Categoría: Rutas
# Código: 62783, Categoría: Rutas
# Código: 80059, Categoría: Rutas
# Código: 61371, Categoría: Rutas
# Código: 61925, Categoría: Rutas
# Código: 80282, Categoría: Rutas
# Código: 22344, Categoría: Rutas
# Código: 22174, Categoría: Rutas
# Código: 23050, Categoría: Rutas
# Código: 22186, Categoría: Rutas
# Código: 22912, Categoría: Rutas
# Código: 80252, Categoría: Rutas
# Código: 80182, Categoría: Rutas
# Código: 22125, Categoría: Rutas
# Código: 80253, Categoría: Rutas
# Código: 80223, Categoría: Rutas
# Código: 81185, Categoría: Rutas
# Código: 21024, Categoría: Rutas
# Código: 80213, Categoría: Rutas
# Código: 12901, Categoría: Rutas
# Código: 41846, Categoría: Rutas
# Código: 41365, Categoría: Rutas
# Código: 42792, Categoría: Rutas
# Código: 11567, Categoría: Rutas
# Código: 11566, Categoría: Rutas
# Código: 11624, Categoría: Rutas
# Código: 81167, Categoría: Rutas
# Código: 81145, Categoría: Rutas
# Código: 11899, Categoría: Rutas
# Código: 11678, Categoría: Rutas
# Código: 11576, Categoría: Rutas
# Código: 81132, Categoría: Rutas
# Código: 62867, Categoría: Rutas
# Código: 62775, Categoría: Rutas
# Código: 12951, Categoría: Rutas
# Código: 62262, Categoría: Rutas
# Código: 11629, Categoría: Rutas
# Código: 81199, Categoría: Rutas
# Código: 11867, Categoría: Rutas
# Código: 62619, Categoría: Rutas
# Código: 81105, Categoría: Rutas
# Código: 81226, Categoría: Rutas
# Código: 81237, Categoría: Rutas
# Código: 41877, Categoría: Rutas
# Código: 12801, Categoría: Rutas
# Código: 42627, Categoría: Rutas
# Código: 42782, Categoría: Rutas
# Código: 42534, Categoría: Rutas
# Código: 42910, Categoría: Rutas
# Código: 42199, Categoría: Rutas
# Código: 62945, Categoría: Rutas
# Código: 42940, Categoría: Rutas
# Código: 42905, Categoría: Rutas
# Código: 42542, Categoría: Rutas
# Código: 81155, Categoría: Rutas
# Código: 81160, Categoría: Rutas
# Código: 13020, Categoría: Rutas
# Código: 13085, Categoría: Rutas
# Código: 81121, Categoría: Rutas
# Código: 81194, Categoría: Rutas
# Código: 12512, Categoría: Rutas
# Código: 12510, Categoría: Rutas
# Código: 12894, Categoría: Rutas
# Código: 12925, Categoría: Rutas
# Código: 12194, Categoría: Rutas
# Código: 12130, Categoría: Rutas
# Código: 12518, Categoría: Rutas
# Código: 12269, Categoría: Rutas
# Código: 81222, Categoría: Rutas
# Código: 81195, Categoría: Rutas
# Código: 81147, Categoría: Rutas
# Código: 81238, Categoría: Rutas
# Código: 81239, Categoría: Rutas
# Código: 81240, Categoría: Rutas
# Código: 80289, Categoría: Rutas
# Código: 81131, Categoría: Rutas
# Código: 11634, Categoría: Rutas
# Código: 11941, Categoría: Rutas
# Código: 62935, Categoría: Rutas
# Código: 62998, Categoría: Rutas
# Código: 11168, Categoría: Rutas
# Código: 62663, Categoría: Rutas
# Código: 82102, Categoría: Rutas
# Código: 81236, Categoría: Rutas
# Código: 81241, Categoría: Rutas
# Código: 62333, Categoría: Rutas
# Código: 80286, Categoría: Rutas
# Código: 81180, Categoría: Rutas
# Código: 81181, Categoría: Rutas
# Código: 11980, Categoría: Rutas
# Código: 12938, Categoría: Rutas
# Código: 11988, Categoría: Rutas
# Código: 81125, Categoría: Rutas
# Código: 81156, Categoría: Rutas
# Código: 12909, Categoría: Rutas
# Código: 12910, Categoría: Rutas
# Código: 82191, Categoría: Rutas
# Código: 82157, Categoría: Rutas
# Código: 82196, Categoría: Rutas
# Código: 41910, Categoría: Rutas
# Código: 82194, Categoría: Rutas
# Código: 82019, Categoría: Rutas
# Código: 41040, Categoría: Rutas
# Código: 82201, Categoría: Rutas
# Código: 41938, Categoría: Rutas
# Código: 41936, Categoría: Rutas
# Código: 41939, Categoría: Rutas
# Código: 82116, Categoría: Rutas
# Código: 41128, Categoría: Rutas
# Código: 41971, Categoría: Rutas
# Código: 41935, Categoría: Rutas
# Código: 82169, Categoría: Rutas
# Código: 82159, Categoría: Rutas
# Código: 82126, Categoría: Rutas
# Código: 11915, Categoría: Rutas
# Código: 11960, Categoría: Rutas
# Código: 82124, Categoría: Rutas
# Código: 82184, Categoría: Rutas
# Código: 11940, Categoría: Rutas
# Código: 11998, Categoría: Rutas
# Código: 81130, Categoría: Rutas
# Código: 81100, Categoría: Rutas
# Código: 82150, Categoría: Rutas
# Código: 81223, Categoría: Rutas
# Código: 81224, Categoría: Rutas
# Código: 82207, Categoría: Rutas
# Código: 41711, Categoría: Rutas
# Código: 82210, Categoría: Rutas
# Código: 82211, Categoría: Rutas
# Código: 81233, Categoría: Rutas
# Código: 82177, Categoría: Rutas
# Código: 12215, Categoría: Rutas
# Código: 12231, Categoría: Rutas
# Código: 82180, Categoría: Rutas
# Código: 82174, Categoría: Rutas
# Código: 82167, Categoría: Rutas
# Código: 12255, Categoría: Rutas
# Código: 12912, Categoría: Rutas
# Código: 82146, Categoría: Rutas
# Código: 12892, Categoría: Rutas
# Código: 82176, Categoría: Rutas
# Código: 82164, Categoría: Rutas
# Código: 82160, Categoría: Rutas
# Código: 82122, Categoría: Rutas
# Código: 12930, Categoría: Rutas
# Código: 12928, Categoría: Rutas
# Código: 12993, Categoría: Rutas
# Código: 82175, Categoría: Rutas
# Código: 13165, Categoría: Rutas
# Código: 82187, Categoría: Rutas
# Código: 82185, Categoría: Rutas
# Código: 12145, Categoría: Rutas
# Código: 12282, Categoría: Rutas
# Código: 22123, Categoría: Rutas
# Código: 81157, Categoría: Rutas
# Código: 12932, Categoría: Rutas
# Código: 41253, Categoría: Rutas
# Código: 82105, Categoría: Rutas
# Código: 82208, Categoría: Rutas
# Código: 81245, Categoría: Rutas
# Código: 82206, Categoría: Rutas
# Código: 41122, Categoría: Rutas
# Código: 41187, Categoría: Rutas
# Código: 82178, Categoría: Rutas
# Código: 11971, Categoría: Rutas
# Código: 41990, Categoría: Rutas
# Código: 62618, Categoría: Rutas
# Código: 81203, Categoría: Rutas
# Código: 11130, Categoría: Rutas
# Código: 13135, Categoría: Rutas
# Código: 62613, Categoría: Rutas
# Código: 12888, Categoría: Rutas
# Código: 822105, Categoría: Rutas
# Código: 12475, Categoría: Creditos
# Código: 82107, Categoría: Creditos
# Código: 82121, Categoría: Creditos
# Código: 82172, Categoría: Creditos
# Código: 82104, Categoría: Creditos
# Código: 12194 NOEMI PEÑA, Categoría: Creditos
# Código: 12970, Categoría: Creditos
# Código: 81177, Categoría: Creditos
# Código: 81243, Categoría: Creditos
# Código: 81129, Categoría: Creditos
# Código: 11981, Categoría: Creditos
# Código: 80115, Categoría: Creditos
# Código: 80139, Categoría: Creditos
# Código: 81149, Categoría: Creditos
# Código: 82170, Categoría: Creditos
# Código: 22126, Categoría: Creditos
# Código: 81212, Categoría: Creditos
# Código: 821640, Categoría: Creditos
# Código: 11921, Categoría: Creditos
# Código: 13055, Categoría: Creditos
# Código: 82123, Categoría: Creditos
# Código: 80066, Categoría: Creditos
# Código: 80101, Categoría: Creditos
# Código: 80240, Categoría: Creditos
# Código: 81133, Categoría: Creditos
# Código: 17068, Categoría: Creditos

# %% [markdown]
# ___

# %% [markdown]
# ### 2_ Ajustes previos al mapeo

# %%
# Obtener semanas únicas y placas únicas
semanas = estacionados_camion['Semana'].unique()
unique_plates = estacionados_camion['Numero_de_placa'].unique()
# Normalizar las patentes en el DataFrame
estacionados_camion['Numero_de_placa'] = estacionados_camion['Numero_de_placa'].str.replace(' ', '').str.upper()

# Columna semana
def agregar_columna_semana(estacionados_camion):
    estacionados_camion['Semana'] = estacionados_camion['Tiempo_de_Inicio'].dt.strftime('%U')
  
# 4. Definir los límites del mapa
def filtrar_por_semana(estacionados_camion, semana):
    return estacionados_camion[estacionados_camion['Semana'] == semana]

# %%
# 6. Calcular clientes visitados
def obtener_clientes_visitados(camiones_placa, ubi_cliente_con_extras):
    clientes_visitados = set()
    for _, camion in camiones_placa.iterrows():
        distancias = ubi_cliente_con_extras.apply(lambda row: calcular_distancia(
            camion['camion_x'], camion['camion_y'], row['LATITUD'], row['LONGITUD']), axis=1)
        cliente_cercano_idx = distancias.idxmin()
        cliente_cercano = ubi_cliente_con_extras.loc[cliente_cercano_idx]
        clientes_visitados.add(cliente_cercano['CODIGO'])
    return clientes_visitados

# %%
# Ahora unimos los extras a ubi_cliente asegurando de que no se agreguen duplicados y que no se pierden los datos de ubi_cliente
ubi_cliente_con_extras = pd.concat([ubi_cliente, df_ubi_empresa, lugares_pago_df], ignore_index=True).drop_duplicates()

# Añadir la columna 'Categoria' al DataFrame 'ubi_cliente_con_extras'
# Mapear los códigos a sus respectivas categorías, si un código no está en el mapeo, se asigna 'Otros'
ubi_cliente_con_extras['Categoria'] = ubi_cliente_con_extras['CODIGO'].map(codigo_categoria_map).fillna('Otros')


# Verificar que no haya valores NaN en la columna 'Categoria'
assert ubi_cliente_con_extras['Categoria'].isna().sum() == 0, "Hay NaNs en la columna 'Categoria'"


# Definir los límites del mapa
min_lon, max_lon = ubi_cliente_con_extras['LONGITUD'].min(), ubi_cliente_con_extras['LONGITUD'].max()
min_lat, max_lat = ubi_cliente_con_extras['LATITUD'].min(), ubi_cliente_con_extras['LATITUD'].max()

# %%
# DataFrame de ejemplo para mapear números de placa a códigos de clientes
placas_a_codigos = pd.DataFrame({
    'Numero_de_placa': ['ABC123', 'DEF456', 'GHI789', 'JKL012', 'MNO345'],
    'CODIGO': [12239, 62005, 77778, 12869, 22024]
})

# Agregar la categoría a 'estacionados_camion' usando 'placas_a_codigos' y 'codigo_categoria_map'
estacionados_camion = estacionados_camion.merge(placas_a_codigos, on='Numero_de_placa', how='left')
estacionados_camion['Categoria'] = estacionados_camion['CODIGO'].map(codigo_categoria_map).fillna('Otros')

# Confirmar que la columna 'Categoria' está presente
print(estacionados_camion.columns)

# Categorías únicas
categorias = estacionados_camion['Categoria'].unique()

print("Categorías únicas:")
print(categorias)
# Out:
# Index(['Indice', 'Numero_de_placa', 'Estado_de_viaje', 'Tiempo_de_Inicio',
#        'Tiempo_Final', 'Duracion', 'Lugar_de_inicio', 'camion_x', 'camion_y',
#        'Semana', 'Semana_del_mes', 'CODIGO', 'Categoria'],
#       dtype='object')
# Categorías únicas:
# ['Visitas Periódicas']

# %% [markdown]
# ###

# %%
# Recrear codigo_categoria_map
codigo_categoria_map = dict(zip(df_tareas['CODIGO'], df_tareas['CATEGORIA']))


# Definir una función para obtener la categoría con un valor por defecto
def obtener_categoria(codigo, default='Otros'):
    return codigo_categoria_map.get(codigo, default)

# Añadir la columna 'Categoria' al DataFrame 'ubi_cliente_con_extras'
ubi_cliente_con_extras['Categoria'] = ubi_cliente_con_extras['CODIGO'].map(codigo_categoria_map)


print("Muestra de codigo_categoria_map:")
for codigo, categoria in list(codigo_categoria_map.items())[:5]:
    print(f"Código: {codigo}, Categoría: {categoria}")
# Out:
# Muestra de codigo_categoria_map:
# Código: 12239, Categoría: Clientes Especiales
# Código: 62005, Categoría: Clientes Especiales
# Código: 77778, Categoría: Clientes Especiales
# Código: 12869, Categoría: Clientes Especiales
# Código: 22024, Categoría: Clientes Especiales

# %%
ubi_cliente_con_extras['CODIGO'] = ubi_cliente_con_extras['CODIGO'].astype(str)
df_tareas['CODIGO'] = df_tareas['CODIGO'].astype(str)

codigos_ubi = set(ubi_cliente_con_extras['CODIGO'])
codigos_tareas = set(df_tareas['CODIGO'])
interseccion = codigos_ubi.intersection(codigos_tareas)
print("Número de códigos que coinciden:", len(interseccion))
print("Ejemplos de códigos que coinciden:", list(interseccion)[:10])
# Out:
# Número de códigos que coinciden: 388
# Ejemplos de códigos que coinciden: ['42905', '21391', '81127', '13065', '21418', '61494', '12910', '12901', '12925', '61833']

# %% [markdown]
# # Creamos el mapa

# %% [markdown]
# ### Mapa 1: crea los iconos de los proyectos pero sin ningun filtro

# %%
# __________________________________ Creación del Mapa Base
for semana in semanas:
    datos_semana = estacionados_camion[estacionados_camion['Semana'] == semana]
    
    # Calcular percentiles para la semana específica
    duracion_25 = datos_semana['Duracion'].quantile(0.25)
    duracion_75 = datos_semana['Duracion'].quantile(0.75)
    
    # Crear el mapa base
    mapa2 = folium.Map(
        location=[datos_semana['camion_x'].mean(), datos_semana['camion_y'].mean()],
        zoom_start=12,
        max_bounds=True,
        min_lat=min_lat,
        max_lat=max_lat,
        min_lon=min_lon,
        max_lon=max_lon
    )
    
    # __________________________________ Crear capas para cada número de placa
    for placa in unique_plates:
        capa_placa = folium.FeatureGroup(name=f"Placa {placa}", show=False)
        camiones_placa = datos_semana[datos_semana['Numero_de_placa'] == placa]
        clientes_visitados = set()
        
        # __________________________________ Agregar marcadores para cada camión de la placa
        for _, camion in camiones_placa.iterrows():
            patente = camion['Numero_de_placa']
            
            # Calcular la distancia del camión a "EMPRESA"
            distancia_a_empresa = calcular_distancia(
                camion['camion_x'], camion['camion_y'], 
                coords_empresa[0], coords_empresa[1]
            )
            
            # Si la distancia es menor que el umbral, excluir este camión
            if distancia_a_empresa < umbral_distancia:
                continue
            
            if patente in iconos_camion_normalizado:
                icon_path = iconos_camion_normalizado[patente]
                icono = folium.CustomIcon(icon_image=icon_path, icon_size=(30, 30))
                
                folium.Marker(
                    location=[camion['camion_x'], camion['camion_y']],
                    popup=f"<b>Camión: {patente}</b><br>Tiempo de Inicio: {camion['Tiempo_de_Inicio']}<br>Duración: {camion['Duracion']}<br>Tiempo Final: {camion['Tiempo_Final']}",
                    tooltip=f"Camión: {patente}",
                    icon=icono
                ).add_to(capa_placa)
            else:
                print(f"Patente no encontrada en el diccionario: {patente}")
            
            # Determinar el color del círculo en función de los percentiles
            if camion['Duracion'] <= duracion_25:
                color_circulo = 'green'
            elif camion['Duracion'] <= duracion_75:
                color_circulo = 'yellow'
            else:
                color_circulo = 'red'

            folium.Circle(
                location=[camion['camion_x'], camion['camion_y']],
                radius=50,
                color=color_circulo,
                fill=True,
                fill_color=color_circulo,
                fill_opacity=0.6,
                weight=2
            ).add_to(capa_placa)
            
            # Encontrar el cliente más cercano y marcarlo como visitado
            distancias = ubi_cliente_con_extras.apply(lambda row: calcular_distancia(
                camion['camion_x'], camion['camion_y'], row['LATITUD'], row['LONGITUD']), axis=1)
            cliente_cercano_idx = distancias.idxmin()
            cliente_cercano = ubi_cliente_con_extras.loc[cliente_cercano_idx]
            clientes_visitados.add(cliente_cercano['CODIGO'])
            
            folium.PolyLine(
                locations=[[camion['camion_x'], camion['camion_y']], 
                           [cliente_cercano['LATITUD'], cliente_cercano['LONGITUD']]],
                color="blue",
                weight=2,
                opacity=0.8
            ).add_to(capa_placa)
        
        for _, cliente in ubi_cliente_con_extras.iterrows():
            if cliente['CODIGO'] in clientes_visitados:
                categoria = codigo_categoria_map.get(str(cliente['CODIGO']), 'Otros')
                icono = iconos_categoria.get(categoria, 'fa-info-circle')
                print(f"Cliente: {cliente['CODIGO']}, Categoría: {categoria}, Icono: {icono}")
        # ... (resto del código para crear el marcador)
                print(f"Cliente: {cliente['CODIGO']}, Categoría: {categoria}, Icono: {icono}")
                print(f"Proyecto original: {df_tareas[df_tareas['CODIGO'] == cliente['CODIGO']]['PROYECTO'].values}")
                
                folium.Marker(
                    location=[cliente['LATITUD'], cliente['LONGITUD']],
                    popup=f"<b>Cliente: {cliente['CODIGO']}</b><br>Nombre: {cliente['NOMCLI']}<br>Categoría: {categoria}",
                    tooltip=f"CODIGO: {cliente['CODIGO']}<br>Nombre: {cliente['NOMCLI']}",
                    icon=folium.Icon(color='red', icon=icono, prefix='fa')
                ).add_to(capa_placa)
                        
                # Añadir capa al mapa
                capa_placa.add_to(mapa2)
        
    # Añadir ubicaciones de la empresa
    for _, empresa in df_ubi_empresa.iterrows():
        folium.Circle(
            location=[empresa['LATITUD'], empresa['LONGITUD']],
            radius=100,
            color="blue",
            fill=True,
            fill_opacity=0.3
        ).add_to(mapa2)
        
        folium.Marker(
            location=[empresa['LATITUD'], empresa['LONGITUD']],
            popup=f"<b>Empresa: {empresa['NOMCLI']}</b>",
            tooltip=f"CODIGO: {empresa['CODIGO']}<br>Nombre: {empresa['NOMCLI']}",
            icon=folium.Icon(color='blue', icon='fa-truck', prefix='fa')
        ).add_to(mapa2)

    # Añadir nuevos lugares de pago
    for _, lugar_pago in lugares_pago_df.iterrows():
        folium.Circle(
            location=[lugar_pago['LATITUD'], lugar_pago['LONGITUD']],
            radius=100,
            color="green",
            fill=True,
            fill_opacity=0.3
        ).add_to(mapa2)
        
        folium.Marker(
            location=[lugar_pago['LATITUD'], lugar_pago['LONGITUD']],
            popup=f"<b>Cliente: {lugar_pago['NOMCLI']}</b>",
            tooltip=lugar_pago['NOMCLI'],
            icon=folium.Icon(color="green", icon="dollar-sign", prefix='fa')
        ).add_to(mapa2)
        
    # Añadir capa de camiones al mapa
    folium.LayerControl().add_to(mapa2)
    
    # Guardar el mapa como archivo HTML
    mapa2.save(f"../mapas_html/mapa_semana_{semana}_proyecto.html")
